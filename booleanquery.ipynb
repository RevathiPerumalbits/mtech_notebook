# %%
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from collections import defaultdict
import re
import string

# Ensure required NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Step 1: Read the dataset
# Assuming you have a folder named 'dataset' with 10 text files.
DATASET_DIR = "covid_data"  # Change this to your dataset folder

def read_files(dataset_dir):
    corpus = {}
    for filename in os.listdir(dataset_dir):
        if filename.endswith(".txt"):
            filepath = os.path.join(dataset_dir, filename)
            with open(filepath, 'r', encoding='utf-8') as file:
                corpus[filename] = file.read()
    return corpus

corpus = read_files(DATASET_DIR)

# Step 2: Preprocess the text (tokenization, normalization, stemming, lemmatization)
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text.lower())

    # Remove punctuation and non-alphanumeric tokens
    tokens = [re.sub(r'\W+', '', token) for token in tokens if token.isalnum()]

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    # Stemming
    '''stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]'''

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    return tokens

# Preprocess each document in the corpus
preprocessed_corpus = {doc: preprocess_text(text) for doc, text in corpus.items()}

# Step 3: Create an inverted index (sorted)
def create_inverted_index(corpus):
    inverted_index = defaultdict(set)
    for doc_id, tokens in corpus.items():
        for token in tokens:
            inverted_index[token].add(doc_id)
    return inverted_index
    

# Sort the inverted index
def sort_inverted_index(corpus):
    inverted_index=create_inverted_index(corpus)
    # Sort the inverted index by keys (terms)
    sorted_inverted_index = {key: sorted(value) for key, value in sorted(inverted_index.items())}
    return sorted_inverted_index
    
inverted_index = create_inverted_index(preprocessed_corpus)
sorted_inverted_index=sort_inverted_index(preprocessed_corpus)

# Step 4: Query the inverted index
def boolean_query(query, inverted_index,all_docs):
    query = query.lower()
    query = query.translate(str.maketrans('', '', string.punctuation))
    query_tokens = query.split()

    if 'and' in query_tokens:
        query_tokens.remove('and')
        result_docs = inverted_index[query_tokens[0]].copy()
        for token in query_tokens[1:]:
           result_docs = result_docs.intersection(set(inverted_index[token]))
    elif 'or' in query_tokens:
        query_tokens.remove('or')
        result_docs = set()
        for token in query_tokens:
            result_docs = result_docs.union(set(inverted_index[token]))
    elif 'not' in query_tokens:
        # NOT operation
        query_tokens.remove('not')
        excluded_docs = inverted_index.get(query_tokens[0], set())
        result_docs = all_docs - excluded_docs
    else:
        result_docs = inverted_index[query_tokens[0]]

    return list(result_docs)
   
# Display results

def display_results(stage, data):
    print(f"\n--- {stage} ---")
    if isinstance(data, dict):
        for key, value in data.items():
            print(f"{key}: {value}")
    else:
        print(data)

# Main execution
if __name__ == "__main__":
    # Read dataset
    display_results("Original Corpus", corpus)

    # Preprocessed corpus
    display_results("Preprocessed Corpus", preprocessed_corpus)

    # Inverted index
    display_results("Inverted Index", sorted_inverted_index)

    # All document names
    all_documents = set(corpus.keys())

# Sample boolean queries
queries = [
    "vaccine AND time",
    "vaccine OR utilized",
    "NOT version",
    "version"
]

# Process and print the results for each query
for query in queries:
    result = boolean_query(query, inverted_index,all_documents)
    print(f"Query: '{query}' => Documents: {result}")
# Out:
# --- Original Corpus ---
# doc1.txt: Facilitators and barriers to COVID-19 vaccine
# uptake among women in two regions of
# Ghana: A qualitative study
#
# Although COVID-19 vaccines are available, evidence suggests that several factors hinder
# or facilitate their use. Several studies have found gender differences in COVID-19 vaccine
# uptake, with women less likely to vaccinate than men in many countries, including Ghana.
# These studies, however, have primarily been quantitative. This study used a qualitative
# approach to examine the facilitators and barriers to vaccine uptake among women in
# Ghana. Using a cross-sectional descriptive qualitative research design, 30 women in the
# Greater Accra and Ashanti regions of Ghana were conveniently sampled and interviewed
# using a semi-structured interview guide. Fifteen (15) interviews were conducted in each
# region. The data were transcribed verbatim and analysed thematically using QSR NVivo
# version 10 software. Among the key factors that facilitate COVID-19 vaccination are the
# desire to protect oneself and family against COVID-19, education about COVID-19 vaccines, seeing others receive the COVID-19 vaccine, and vaccine being cost-free. On the
# other hand, long queues at the vaccination centres, fear of side effects, misconceptions
# about the vaccines, and shortage of vaccines were the main barriers against COVID-19 vaccination. The study results show that individual, institutional, and vaccine-related factors
# facilitate or hinder COVID-19 vaccination among women. Addressing these factors need
# continuous comprehensive health education, and ensuring vaccine availability at vaccination sites will improve women’s uptake of the COVID-19 vaccines.
# doc2.txt: The level and determinants of COVID-19
# vaccine acceptance in Ghana
#
# As part of the efforts to curb the COVID-19 pandemic, the government of Ghana has
# received several shipments of approved vaccines, and administration has begun in the
# country. Studies examining the determinants of COVID-19 vaccine acceptance in Ghana
# were mostly conducted before the vaccination exercise. Vaccine acceptance decisions
# however vary with time and hence, peoples’ decisions may have changed once vaccines
# became accessible. This study examines the level and determinants of COVID-19 vaccine
# acceptance among adult Ghanaians during the vaccination exercise.
#
# Methods
# The study was a cross-sectional online survey involving Ghanaian adults (18 years and
# above) eligible to take the COVID-19 vaccine. The study was conducted from 18th May
# 2021 to 14th July 2021 and the questionnaire was answered by 362 respondents. Snowball
# sampling technique was utilized to obtain the respondents. Probit regression analysis was
# used to identify factors influencing COVID-19 vaccine acceptance.
# doc3.txt: Misinformation of COVID‑19
#
# vaccines and vaccine hesitancy
# The current study examined various types of misinformation related to the COVID-19 vaccines and
# their relationships to vaccine hesitancy and refusal. Study 1 asked a sample of full-time working
# professionals in the US (n = 505) about possible misinformation they were exposed to related to the
# COVID-19 vaccines. Study 2 utilized an online survey to examine U.S. college students’ (n = 441)
# knowledge about COVID-19 vaccines, and its associations with vaccine hesitancy and behavioral
# intention to get a COVID-19 vaccine. Analysis of open-ended responses in Study 1 revealed that 57.6%
# reported being exposed to conspiratorial misinformation such as COVID-19 vaccines are harmful
# and dangerous. The results of a structural equation modeling analysis for Study 2 supported our
# hypotheses predicting a negative association between the knowledge level and vaccine hesitancy and
# between vaccine hesitancy and behavioral intention. Vaccine hesitancy mediated the relationship
# between the vaccine knowledge and behavioral intention. Findings across these studies suggest
# exposure to misinformation and believing it as true could increase vaccine hesitancy and reduce
# behavioral intention to get vaccinated.
# Health misinformation can kill people, both directly and indirectly. During a public health crisis such as the
# COVID-19 pandemic, exposure to misinformation about the virus’ spread, symptoms of infection, testing opportunities, and prevention methods can lead to erroneous appraisals of the threat, maladaptive coping behaviors,
# and a range of fatal consequences. More critically, misinformation about the new COVID-19 vaccines and their
# development process has the potential to induce high levels of vaccine hesitancy in the p
# ­ ublic1,2, preventing vaccination rates sufficient for achieving herd immunity. Due to the high level of uncertainty caused by the pandemic
# and the relatively fast speed of vaccine development compared to other types of traditional vaccines, the public
# naturally sought out information to address their vaccine concerns and guide critical decision-making such as
# whether to get vaccinated or not. However, separating relevant and valid information from false and distorted
# misinformation about COVID-19 vaccines is difficult when a vast amount of material is being conveyed through
# media outlets and websites of varying reliability and accuracy. One critically important challenge to obtaining
# reliable, accurate COVID-19 vaccine information includes the pervasive, unsolicited, and dubious pseudo-news
# items communicated via online and social media platforms by various types of ­actors1.
# Because many people acquire and share news via social ­media3, misinformation can spread quickly through
# their social networks, and the likelihood of exposure to disinformation and misrepresentations about the vaccine
# from unverified sources is high. The resulting increase in public anxiety and negative emotional and behavioral
# responses complicates the process of advising the public through health experts and agencies such as the CDC
# and WHO. The current research focuses on people’s perceptions of the nature and types of misinformation about
# COVID-19 ­vaccines4. Additionally, this research examines the relationship between knowledge about COVID-19
# vaccines, including its relevant misinformation, and vaccine hesitancy and refusal.
# By acknowledging the serious negative impact of health misinformation and its spread, research in infodemiology (i.e., epidemiology of (mis)information5,6) identifies the knowledge translation gap between evidence
# produced by experts and the public’s actual practices and beliefs. Research has identified various quality markers (e.g., source, technical, and content criteria) and their relations with outcome variables (e.g., health-related
# knowledge and behavioral changes) necessary for effective health communication on the internet. Studies have
# shown both algorithmic-based correction on Facebook and social correction via anonymous commenters can
# be effective in reducing beliefs in health misinformation. However, people who believe in conspiracy theories
# tend to discredit algorithm-based c­ orrections7,8.
# More research is needed to (a) observe and define the trends and prevalence of health misinformation on
# various types of social media; (b) understand how relevant misinformation is shared; (c) evaluate the reach and
# influence of misinformation; and (d) develop and test effective i­nterventions9,10. With the aim of increasing
#
# doc4.txt: HUMAN VACCINES & IMMUNOTHERAPEUTICS
#
# Confidence in COVID-19 vaccine effectiveness and safety and its effect on vaccine
# COVID-19 is a major public health threat associated with increased disease burden, mortality, and economic
# loss to countries and communities. Safe and efficacious COVID-19 vaccines are key in halting and reversing
# the pandemic. Low confidence in vaccines has been one of the factors leading to hesitancy. We aimed to
# assess the COVID-19 vaccine confidence (safety and effectiveness), associated factors, and its effects on
# vaccine uptake among general community members in Tanzania. This was a community-based crosssectional survey conducted from December 2021 to April 2022 in six regions of Tanzania mainland and two
# regions in Zanzibar. Participants were interviewed using an electronic questionnaire. Multiple logistic
# regression models estimated odds ratios (ORs) and 95% confidence interval (CI) for factors associated
# with vaccine confidence. All analyses were performed using SPSS version 25.0. The study enrolled 3470
# general Tanzanian community members; their mean age was 40.3 (standard deviation ±14.9) years, and
# 34% were males. The proportion of COVID-19 vaccine confidence was 54.6%. Geographical region,
# residence area, COVID-19 disease risk perception, and good knowledge of COVID-19 vaccines were
# significantly associated with COVID-19 vaccine confidence. Confidence in COVID-19 vaccines was asso­
# ciated with over three times higher odds of vaccine uptake. Confidence in COVID-19 vaccines was low in
# Tanzania. Innovative community engagement strategies and region-specific interventions are needed to
# improve comprehensive knowledge and address community perceptions and attitudes toward COVID-19
# vaccines.
#
#
# Introduction
# Vaccine confidence is an issue of public health concern, espe­
# cially in the era of emerging and reemerging infectious diseases.
# It is defined by public perceptions of three components: vaccine
# safety, effectiveness, and importance.1 Lack of trust and confi­
# dence in vaccines is an important determinant of vaccine hesi­
# tancy, and it influences uptake, affects national immunization
# targets, and increases outbreaks of vaccine-preventable
# diseases.1–3 Hesitancy in available childhood and other vaccines
# has led to a resurgence of vaccine-preventable diseases such as
# measles and diarrhea, and in some instances, it has affected polio
# eradication success efforts, threatening years of progress in the
# global fight against infectious diseases.4,5 The World Health
# Organization (WHO) has identified reluctance or refusal to
# vaccinate as one of the 10 global health security threats in 2019
# that need to be tracked and addressed by countries.6
#
#
# --- Preprocessed Corpus ---
# doc1.txt: ['facilitator', 'barrier', 'vaccine', 'uptake', 'among', 'woman', 'two', 'region', 'ghana', 'qualitative', 'study', 'although', 'vaccine', 'available', 'evidence', 'suggests', 'several', 'factor', 'hinder', 'facilitate', 'use', 'several', 'study', 'found', 'gender', 'difference', 'vaccine', 'uptake', 'woman', 'le', 'likely', 'vaccinate', 'men', 'many', 'country', 'including', 'ghana', 'study', 'however', 'primarily', 'quantitative', 'study', 'used', 'qualitative', 'approach', 'examine', 'facilitator', 'barrier', 'vaccine', 'uptake', 'among', 'woman', 'ghana', 'using', 'descriptive', 'qualitative', 'research', 'design', '30', 'woman', 'greater', 'accra', 'ashanti', 'region', 'ghana', 'conveniently', 'sampled', 'interviewed', 'using', 'interview', 'guide', 'fifteen', '15', 'interview', 'conducted', 'region', 'data', 'transcribed', 'verbatim', 'analysed', 'thematically', 'using', 'qsr', 'nvivo', 'version', '10', 'software', 'among', 'key', 'factor', 'facilitate', 'vaccination', 'desire', 'protect', 'oneself', 'family', 'education', 'vaccine', 'seeing', 'others', 'receive', 'vaccine', 'vaccine', 'hand', 'long', 'queue', 'vaccination', 'centre', 'fear', 'side', 'effect', 'misconception', 'vaccine', 'shortage', 'vaccine', 'main', 'barrier', 'vaccination', 'study', 'result', 'show', 'individual', 'institutional', 'factor', 'facilitate', 'hinder', 'vaccination', 'among', 'woman', 'addressing', 'factor', 'need', 'continuous', 'comprehensive', 'health', 'education', 'ensuring', 'vaccine', 'availability', 'vaccination', 'site', 'improve', 'woman', 'uptake', 'vaccine']
# doc2.txt: ['level', 'determinant', 'vaccine', 'acceptance', 'ghana', 'part', 'effort', 'curb', 'pandemic', 'government', 'ghana', 'received', 'several', 'shipment', 'approved', 'vaccine', 'administration', 'begun', 'country', 'study', 'examining', 'determinant', 'vaccine', 'acceptance', 'ghana', 'mostly', 'conducted', 'vaccination', 'exercise', 'vaccine', 'acceptance', 'decision', 'however', 'vary', 'time', 'hence', 'people', 'decision', 'may', 'changed', 'vaccine', 'became', 'accessible', 'study', 'examines', 'level', 'determinant', 'vaccine', 'acceptance', 'among', 'adult', 'ghanaians', 'vaccination', 'exercise', 'method', 'study', 'online', 'survey', 'involving', 'ghanaian', 'adult', '18', 'year', 'eligible', 'take', 'vaccine', 'study', 'conducted', '18th', 'may', '2021', '14th', 'july', '2021', 'questionnaire', 'answered', '362', 'respondent', 'snowball', 'sampling', 'technique', 'utilized', 'obtain', 'respondent', 'probit', 'regression', 'analysis', 'used', 'identify', 'factor', 'influencing', 'vaccine', 'acceptance']
# doc3.txt: ['misinformation', 'vaccine', 'vaccine', 'hesitancy', 'current', 'study', 'examined', 'various', 'type', 'misinformation', 'related', 'vaccine', 'relationship', 'vaccine', 'hesitancy', 'refusal', 'study', '1', 'asked', 'sample', 'working', 'professional', 'u', 'n', '505', 'possible', 'misinformation', 'exposed', 'related', 'vaccine', 'study', '2', 'utilized', 'online', 'survey', 'examine', 'college', 'student', 'n', '441', 'knowledge', 'vaccine', 'association', 'vaccine', 'hesitancy', 'behavioral', 'intention', 'get', 'vaccine', 'analysis', 'response', 'study', '1', 'revealed', 'reported', 'exposed', 'conspiratorial', 'misinformation', 'vaccine', 'harmful', 'dangerous', 'result', 'structural', 'equation', 'modeling', 'analysis', 'study', '2', 'supported', 'hypothesis', 'predicting', 'negative', 'association', 'knowledge', 'level', 'vaccine', 'hesitancy', 'vaccine', 'hesitancy', 'behavioral', 'intention', 'vaccine', 'hesitancy', 'mediated', 'relationship', 'vaccine', 'knowledge', 'behavioral', 'intention', 'finding', 'across', 'study', 'suggest', 'exposure', 'misinformation', 'believing', 'true', 'could', 'increase', 'vaccine', 'hesitancy', 'reduce', 'behavioral', 'intention', 'get', 'vaccinated', 'health', 'misinformation', 'kill', 'people', 'directly', 'indirectly', 'public', 'health', 'crisis', 'pandemic', 'exposure', 'misinformation', 'virus', 'spread', 'symptom', 'infection', 'testing', 'opportunity', 'prevention', 'method', 'lead', 'erroneous', 'appraisal', 'threat', 'maladaptive', 'coping', 'behavior', 'range', 'fatal', 'consequence', 'critically', 'misinformation', 'new', 'vaccine', 'development', 'process', 'potential', 'induce', 'high', 'level', 'vaccine', 'hesitancy', 'p', 'preventing', 'vaccination', 'rate', 'sufficient', 'achieving', 'herd', 'immunity', 'due', 'high', 'level', 'uncertainty', 'caused', 'pandemic', 'relatively', 'fast', 'speed', 'vaccine', 'development', 'compared', 'type', 'traditional', 'vaccine', 'public', 'naturally', 'sought', 'information', 'address', 'vaccine', 'concern', 'guide', 'critical', 'whether', 'get', 'vaccinated', 'however', 'separating', 'relevant', 'valid', 'information', 'false', 'distorted', 'misinformation', 'vaccine', 'difficult', 'vast', 'amount', 'material', 'conveyed', 'medium', 'outlet', 'website', 'varying', 'reliability', 'accuracy', 'one', 'critically', 'important', 'challenge', 'obtaining', 'reliable', 'accurate', 'vaccine', 'information', 'includes', 'pervasive', 'unsolicited', 'dubious', 'item', 'communicated', 'via', 'online', 'social', 'medium', 'platform', 'various', 'type', 'many', 'people', 'acquire', 'share', 'news', 'via', 'social', 'misinformation', 'spread', 'quickly', 'social', 'network', 'likelihood', 'exposure', 'disinformation', 'misrepresentation', 'vaccine', 'unverified', 'source', 'high', 'resulting', 'increase', 'public', 'anxiety', 'negative', 'emotional', 'behavioral', 'response', 'complicates', 'process', 'advising', 'public', 'health', 'expert', 'agency', 'cdc', 'current', 'research', 'focus', 'people', 'perception', 'nature', 'type', 'misinformation', 'additionally', 'research', 'examines', 'relationship', 'knowledge', 'vaccine', 'including', 'relevant', 'misinformation', 'vaccine', 'hesitancy', 'refusal', 'acknowledging', 'serious', 'negative', 'impact', 'health', 'misinformation', 'spread', 'research', 'infodemiology', 'epidemiology', 'mi', 'identifies', 'knowledge', 'translation', 'gap', 'evidence', 'produced', 'expert', 'public', 'actual', 'practice', 'belief', 'research', 'identified', 'various', 'quality', 'marker', 'source', 'technical', 'content', 'criterion', 'relation', 'outcome', 'variable', 'knowledge', 'behavioral', 'change', 'necessary', 'effective', 'health', 'communication', 'internet', 'study', 'shown', 'correction', 'facebook', 'social', 'correction', 'via', 'anonymous', 'commenters', 'effective', 'reducing', 'belief', 'health', 'misinformation', 'however', 'people', 'believe', 'conspiracy', 'theory', 'tend', 'discredi ...
# doc4.txt: ['human', 'vaccine', 'immunotherapeutics', 'confidence', 'vaccine', 'effectiveness', 'safety', 'effect', 'vaccine', 'major', 'public', 'health', 'threat', 'associated', 'increased', 'disease', 'burden', 'mortality', 'economic', 'loss', 'country', 'community', 'safe', 'efficacious', 'vaccine', 'key', 'halting', 'reversing', 'pandemic', 'low', 'confidence', 'vaccine', 'one', 'factor', 'leading', 'hesitancy', 'aimed', 'ass', 'vaccine', 'confidence', 'safety', 'effectiveness', 'associated', 'factor', 'effect', 'vaccine', 'uptake', 'among', 'general', 'community', 'member', 'tanzania', 'crosssectional', 'survey', 'conducted', 'december', '2021', 'april', '2022', 'six', 'region', 'tanzania', 'mainland', 'two', 'region', 'zanzibar', 'participant', 'interviewed', 'using', 'electronic', 'questionnaire', 'multiple', 'logistic', 'regression', 'model', 'estimated', 'odds', 'ratio', 'or', '95', 'confidence', 'interval', 'ci', 'factor', 'associated', 'vaccine', 'confidence', 'analysis', 'performed', 'using', 'spss', 'version', 'study', 'enrolled', '3470', 'general', 'tanzanian', 'community', 'member', 'mean', 'age', 'standard', 'deviation', 'year', '34', 'male', 'proportion', 'vaccine', 'confidence', 'geographical', 'region', 'residence', 'area', 'disease', 'risk', 'perception', 'good', 'knowledge', 'vaccine', 'significantly', 'associated', 'vaccine', 'confidence', 'confidence', 'vaccine', 'ciated', 'three', 'time', 'higher', 'odds', 'vaccine', 'uptake', 'confidence', 'vaccine', 'low', 'tanzania', 'innovative', 'community', 'engagement', 'strategy', 'intervention', 'needed', 'improve', 'comprehensive', 'knowledge', 'address', 'community', 'perception', 'attitude', 'toward', 'vaccine', 'introduction', 'vaccine', 'confidence', 'issue', 'public', 'health', 'concern', 'cially', 'era', 'emerging', 'reemerging', 'infectious', 'disease', 'defined', 'public', 'perception', 'three', 'component', 'vaccine', 'safety', 'effectiveness', 'lack', 'trust', 'dence', 'vaccine', 'important', 'determinant', 'vaccine', 'tancy', 'influence', 'uptake', 'affect', 'national', 'immunization', 'target', 'increase', 'outbreak', 'hesitancy', 'available', 'childhood', 'vaccine', 'led', 'resurgence', 'disease', 'measles', 'diarrhea', 'instance', 'affected', 'polio', 'eradication', 'success', 'effort', 'threatening', 'year', 'progress', 'global', 'fight', 'infectious', 'world', 'health', 'organization', 'identified', 'reluctance', 'refusal', 'vaccinate', 'one', '10', 'global', 'health', 'security', 'threat', '2019', 'need', 'tracked', 'addressed']
#
# --- Inverted Index ---
# 1: ['doc3.txt']
# 10: ['doc1.txt', 'doc4.txt']
# 14th: ['doc2.txt']
# 15: ['doc1.txt']
# 18: ['doc2.txt']
# 18th: ['doc2.txt']
# 2: ['doc3.txt']
# 2019: ['doc4.txt']
# 2021: ['doc2.txt', 'doc4.txt']
# 2022: ['doc4.txt']
# 30: ['doc1.txt']
# 34: ['doc4.txt']
# 3470: ['doc4.txt']
# 362: ['doc2.txt']
# 441: ['doc3.txt']
# 505: ['doc3.txt']
# 95: ['doc4.txt']
# acceptance: ['doc2.txt']
# accessible: ['doc2.txt']
# accra: ['doc1.txt']
# accuracy: ['doc3.txt']
# accurate: ['doc3.txt']
# achieving: ['doc3.txt']
# acknowledging: ['doc3.txt']
# acquire: ['doc3.txt']
# across: ['doc3.txt']
# actual: ['doc3.txt']
# additionally: ['doc3.txt']
# address: ['doc3.txt', 'doc4.txt']
# addressed: ['doc4.txt']
# addressing: ['doc1.txt']
# administration: ['doc2.txt']
# adult: ['doc2.txt']
# advising: ['doc3.txt']
# affect: ['doc4.txt']
# affected: ['doc4.txt']
# age: ['doc4.txt']
# agency: ['doc3.txt']
# aim: ['doc3.txt']
# aimed: ['doc4.txt']
# although: ['doc1.txt']
# among: ['doc1.txt', 'doc2.txt', 'doc4.txt']
# amount: ['doc3.txt']
# analysed: ['doc1.txt']
# analysis: ['doc2.txt', 'doc3.txt', 'doc4.txt']
# anonymous: ['doc3.txt']
# answered: ['doc2.txt']
# anxiety: ['doc3.txt']
# appraisal: ['doc3.txt']
# approach: ['doc1.txt']
# approved: ['doc2.txt']
# april: ['doc4.txt']
# area: ['doc4.txt']
# ashanti: ['doc1.txt']
# asked: ['doc3.txt']
# ass: ['doc4.txt']
# associated: ['doc4.txt']
# association: ['doc3.txt']
# attitude: ['doc4.txt']
# availability: ['doc1.txt']
# available: ['doc1.txt', 'doc4.txt']
# b: ['doc3.txt']
# barrier: ['doc1.txt']
# became: ['doc2.txt']
# begun: ['doc2.txt']
# behavior: ['doc3.txt']
# behavioral: ['doc3.txt']
# belief: ['doc3.txt']
# believe: ['doc3.txt']
# believing: ['doc3.txt']
# burden: ['doc4.txt']
# c: ['doc3.txt']
# caused: ['doc3.txt']
# cdc: ['doc3.txt']
# centre: ['doc1.txt']
# challenge: ['doc3.txt']
# change: ['doc3.txt']
# changed: ['doc2.txt']
# childhood: ['doc4.txt']
# ci: ['doc4.txt']
# cially: ['doc4.txt']
# ciated: ['doc4.txt']
# college: ['doc3.txt']
# commenters: ['doc3.txt']
# communicated: ['doc3.txt']
# communication: ['doc3.txt']
# community: ['doc4.txt']
# compared: ['doc3.txt']
# complicates: ['doc3.txt']
# component: ['doc4.txt']
# comprehensive: ['doc1.txt', 'doc4.txt']
# concern: ['doc3.txt', 'doc4.txt']
# conducted: ['doc1.txt', 'doc2.txt', 'doc4.txt']
# confidence: ['doc4.txt']
# consequence: ['doc3.txt']
# conspiracy: ['doc3.txt']
# conspiratorial: ['doc3.txt']
# content: ['doc3.txt']
# continuous: ['doc1.txt']
# conveniently: ['doc1.txt']
# conveyed: ['doc3.txt']
# coping: ['doc3.txt']
# correction: ['doc3.txt']
# could: ['doc3.txt']
# country: ['doc1.txt', 'doc2.txt', 'doc4.txt']
# crisis: ['doc3.txt']
# criterion: ['doc3.txt']
# critical: ['doc3.txt']
# critically: ['doc3.txt']
# crosssectional: ['doc4.txt']
# curb: ['doc2.txt']
# current: ['doc3.txt']
# dangerous: ['doc3.txt']
# data: ['doc1.txt']
# december: ['doc4.txt']
# decision: ['doc2.txt']
# define: ['doc3.txt']
# defined: ['doc4.txt']
# dence: ['doc4.txt']
# descriptive: ['doc1.txt']
# design: ['doc1.txt']
# desire: ['doc1.txt']
# determinant: ['doc2.txt', 'doc4.txt']
# develop: ['doc3.txt']
# development: ['doc3.txt']
# deviation: ['doc4.txt']
# diarrhea: ['doc4.txt']
# difference: ['doc1.txt']
# difficult: ['doc3.txt']
# directly: ['doc3.txt']
# discredit: ['doc3.txt']
# disease: ['doc4.txt']
# disinformation: ['doc3.txt']
# distorted: ['doc3.txt']
# dubious: ['doc3.txt']
# due: ['doc3.txt']
# economic: ['doc4.txt']
# education: ['doc1.txt']
# effect: ['doc1.txt', 'doc4.txt']
# effective: ['doc3.txt']
# effectiveness: ['doc4.txt']
# efficacious: ['doc4.txt']
# effort: ['doc2.txt', 'doc4.txt']
# electronic: ['doc4.txt']
# eligible: ['doc2.txt']
# emerging: ['doc4.txt']
# emotional: ['doc3.txt']
# engagement: ['doc4.txt']
# enrolled: ['doc4.txt']
# ensuring: ['doc1.txt']
# epidemiology: ['doc3.txt']
# equation: ['doc3.txt']
# era: ['doc4.txt']
# eradication: ['doc4.txt']
# erroneous: ['doc3.txt']
# estimated: ['doc4.txt']
# evaluate: ['doc3.txt']
# evidence: ['doc1.txt', 'doc3.txt']
# examine: ['doc1.txt', 'doc3.txt']
# examined: ['doc3.txt']
# examines: ['doc2.txt', 'doc3.txt']
# examining: ['doc2.txt']
# exercise: ['doc2.txt']
# expert: ['doc3.txt']
# exposed: ['doc3.txt']
# exposure: ['doc3.txt']
# facebook: ['doc3.txt']
# facilitate: ['doc1.txt']
# facilitator: ['doc1.txt']
# factor: ['doc1.txt', 'doc2.txt', 'doc4.txt']
# false: ['doc3.txt']
# family: ['doc1.txt']
# fast: ['doc3.txt']
# fatal: ['doc3.txt']
# fear: ['doc1.txt']
# fifteen: ['doc1.txt']
# fight: ['doc4.txt']
# finding: ['doc3.txt']
# focus: ['doc3.txt']
# found: ['doc1.txt']
# gap: ['doc3.txt']
# gender: ['doc1.txt']
# general: ['doc4.txt']
# geographical: ['doc4.txt']
# get: ['doc3.txt']
# ghana: ['doc1.txt', 'doc2.txt']
# ghanaian: ['doc2.txt']
# ghanaians: ['doc2.txt']
# global: ['doc4.txt']
# good: ['doc4.txt']
# government: ['doc2.txt']
# greater: ['doc1.txt']
# guide: ['doc1.txt', 'doc3.txt']
# halting: ['doc4.txt']
# hand: ['doc1.txt']
# harmful: ['doc3.txt']
# health: ['doc1.txt', 'doc3.txt', 'doc4.txt']
# hence: ['doc2.txt']
# herd: ['doc3.txt']
# hesitancy: ['doc3.txt', 'doc4.txt']
# high: ['doc3.txt']
# higher: ['doc4.txt']
# hinder: ['doc1.txt']
# however: ['doc1.txt', 'doc2.txt', 'doc3.txt']
# human: ['doc4.txt']
# hypothesis: ['doc3.txt']
# identified: ['doc3.txt', 'doc4.txt']
# identifies: ['doc3.txt']
# identify: ['doc2.txt']
# immunity: ['doc3.txt']
# immunization: ['doc4.txt']
# immunotherapeutics: ['doc4.txt']
# impact: ['doc3.txt']
# important: ['doc3.txt', 'doc4.txt']
# improve: ['doc1.txt', 'doc4.txt']
# includes: ['doc3.txt']
# including: ['doc1.txt', 'doc3.txt']
# increase: ['doc3.txt', 'doc4.txt']
# increased: ['doc4.txt']
# increasing: ['doc3.txt']
# indirectly: ['doc3.txt']
# individual: ['doc1.txt']
# induce: ['doc3.txt']
# infection: ['doc3.txt']
# infectious: ['doc4.txt']
# influence: ['doc3.txt', 'doc4.txt']
# influencing: ['doc2.txt']
# infodemiology: ['doc3.txt']
# information: ['doc3.txt']
# innovative: ['doc4.txt']
# instance: ['doc4.txt']
# institutional: ['doc1.txt']
# intention: ['doc3.txt']
# internet: ['doc3.txt']
# interval: ['doc4.txt']
# intervention: ['doc4.txt']
# interview: ['doc1.txt']
# interviewed: ['doc1.txt', 'doc4.txt']
# introduction: ['doc4.txt']
# involving: ['doc2.txt']
# issue: ['doc4.txt']
# item: ['doc3.txt']
# july: ['doc2.txt']
# key: ['doc1.txt', 'doc4.txt']
# kill: ['doc3.txt']
# knowledge: ['doc3.txt', 'doc4.txt']
# lack: ['doc4.txt']
# le: ['doc1.txt']
# lead: ['doc3.txt']
# leading: ['doc4.txt']
# led: ['doc4.txt']
# level: ['doc2.txt', 'doc3.txt']
# likelihood: ['doc3.txt']
# likely: ['doc1.txt']
# logistic: ['doc4.txt']
# long: ['doc1.txt']
# loss: ['doc4.txt']
# low: ['doc4.txt']
# main: ['doc1.txt']
# mainland: ['doc4.txt']
# major: ['doc4.txt']
# maladaptive: ['doc3.txt']
# male: ['doc4.txt']
# many: ['doc1.txt', 'doc3.txt']
# marker: ['doc3.txt']
# material: ['doc3.txt']
# may: ['doc2.txt']
# mean: ['doc4.txt']
# measles: ['doc4.txt']
# mediated: ['doc3.txt']
# medium: ['doc3.txt']
# member: ['doc4.txt']
# men: ['doc1.txt']
# method: ['doc2.txt', 'doc3.txt']
# mi: ['doc3.txt']
# misconception: ['doc1.txt']
# misinformation: ['doc3.txt']
# misrepresentation: ['doc3.txt']
# model: ['doc4.txt']
# modeling: ['doc3.txt']
# mortality: ['doc4.txt']
# mostly: ['doc2.txt']
# multiple: ['doc4.txt']
# n: ['doc3.txt']
# national: ['doc4.txt']
# naturally: ['doc3.txt']
# nature: ['doc3.txt']
# necessary: ['doc3.txt']
# need: ['doc1.txt', 'doc4.txt']
# needed: ['doc3.txt', 'doc4.txt']
# negative: ['doc3.txt']
# network: ['doc3.txt']
# new: ['doc3.txt']
# news: ['doc3.txt']
# nvivo: ['doc1.txt']
# observe: ['doc3.txt']
# obtain: ['doc2.txt']
# obtaining: ['doc3.txt']
# odds: ['doc4.txt']
# one: ['doc3.txt', 'doc4.txt']
# oneself: ['doc1.txt']
# online: ['doc2.txt', 'doc3.txt']
# opportunity: ['doc3.txt']
# or: ['doc4.txt']
# organization: ['doc4.txt']
# others: ['doc1.txt']
# outbreak: ['doc4.txt']
# outcome: ['doc3.txt']
# outlet: ['doc3.txt']
# p: ['doc3.txt']
# pandemic: ['doc2.txt', 'doc3.txt', 'doc4.txt']
# part: ['doc2.txt']
# participant: ['doc4.txt']
# people: ['doc2.txt', 'doc3.txt']
# perception: ['doc3.txt', 'doc4.txt']
# performed: ['doc4.txt']
# pervasive: ['doc3.txt']
# platform: ['doc3.txt']
# polio: ['doc4.txt']
# possible: ['doc3.txt']
# potential: ['doc3.txt']
# practice: ['doc3.txt']
# predicting: ['doc3.txt']
# prevalence: ['doc3.txt']
# preventing: ['doc3.txt']
# prevention: ['doc3.txt']
# primarily: ['doc1.txt']
# probit: ['doc2.txt']
# process: ['doc3.txt']
# produced: ['doc3.txt']
# professional: ['doc3.txt']
# progress: ['doc4.txt']
# proportion: ['doc4.txt']
# protect: ['doc1.txt']
# public: ['doc3.txt', 'doc4.txt']
# qsr: ['doc1.txt']
# qualitative: ['doc1.txt']
# quality: ['doc3.txt']
# quantitative: ['doc1.txt']
# questionnaire: ['doc2.txt', 'doc4.txt']
# queue: ['doc1.txt']
# quickly: ['doc3.txt']
# range: ['doc3.txt']
# rate: ['doc3.txt']
# ratio: ['doc4.txt']
# reach: ['doc3.txt']
# receive: ['doc1.txt']
# received: ['doc2.txt']
# reduce: ['doc3.txt']
# reducing: ['doc3.txt']
# reemerging: ['doc4.txt']
# refusal: ['doc3.txt', 'doc4.txt']
# region: ['doc1.txt', 'doc4.txt']
# regression: ['doc2.txt', 'doc4.txt']
# related: ['doc3.txt']
# relation: ['doc3.txt']
# relationship: ['doc3.txt']
# relatively: ['doc3.txt']
# relevant: ['doc3.txt']
# reliability: ['doc3.txt']
# reliable: ['doc3.txt']
# reluctance: ['doc4.txt']
# reported: ['doc3.txt']
# research: ['doc1.txt', 'doc3.txt']
# residence: ['doc4.txt']
# respondent: ['doc2.txt']
# response: ['doc3.txt']
# result: ['doc1.txt', 'doc3.txt']
# resulting: ['doc3.txt']
# resurgence: ['doc4.txt']
# revealed: ['doc3.txt']
# reversing: ['doc4.txt']
# risk: ['doc4.txt']
# safe: ['doc4.txt']
# safety: ['doc4.txt']
# sample: ['doc3.txt']
# sampled: ['doc1.txt']
# sampling: ['doc2.txt']
# security: ['doc4.txt']
# seeing: ['doc1.txt']
# separating: ['doc3.txt']
# serious: ['doc3.txt']
# several: ['doc1.txt', 'doc2.txt']
# share: ['doc3.txt']
# shared: ['doc3.txt']
# shipment: ['doc2.txt']
# shortage: ['doc1.txt']
# show: ['doc1.txt']
# shown: ['doc3.txt']
# side: ['doc1.txt']
# significantly: ['doc4.txt']
# site: ['doc1.txt']
# six: ['doc4.txt']
# snowball: ['doc2.txt']
# social: ['doc3.txt']
# software: ['doc1.txt']
# sought: ['doc3.txt']
# source: ['doc3.txt']
# speed: ['doc3.txt']
# spread: ['doc3.txt']
# spss: ['doc4.txt']
# standard: ['doc4.txt']
# strategy: ['doc4.txt']
# structural: ['doc3.txt']
# student: ['doc3.txt']
# study: ['doc1.txt', 'doc2.txt', 'doc3.txt', 'doc4.txt']
# success: ['doc4.txt']
# sufficient: ['doc3.txt']
# suggest: ['doc3.txt']
# suggests: ['doc1.txt']
# supported: ['doc3.txt']
# survey: ['doc2.txt', 'doc3.txt', 'doc4.txt']
# symptom: ['doc3.txt']
# take: ['doc2.txt']
# tancy: ['doc4.txt']
# tanzania: ['doc4.txt']
# tanzanian: ['doc4.txt']
# target: ['doc4.txt']
# technical: ['doc3.txt']
# technique: ['doc2.txt']
# tend: ['doc3.txt']
# test: ['doc3.txt']
# testing: ['doc3.txt']
# thematically: ['doc1.txt']
# theory: ['doc3.txt']
# threat: ['doc3.txt', 'doc4.txt']
# threatening: ['doc4.txt']
# three: ['doc4.txt']
# time: ['doc2.txt', 'doc4.txt']
# toward: ['doc4.txt']
# tracked: ['doc4.txt']
# traditional: ['doc3.txt']
# transcribed: ['doc1.txt']
# translation: ['doc3.txt']
# trend: ['doc3.txt']
# true: ['doc3.txt']
# trust: ['doc4.txt']
# two: ['doc1.txt', 'doc4.txt']
# type: ['doc3.txt']
# u: ['doc3.txt']
# uncertainty: ['doc3.txt']
# understand: ['doc3.txt']
# unsolicited: ['doc3.txt']
# unverified: ['doc3.txt']
# uptake: ['doc1.txt', 'doc4.txt']
# use: ['doc1.txt']
# used: ['doc1.txt', 'doc2.txt']
# using: ['doc1.txt', 'doc4.txt']
# utilized: ['doc2.txt', 'doc3.txt']
# vaccinate: ['doc1.txt', 'doc4.txt']
# vaccinated: ['doc3.txt']
# vaccination: ['doc1.txt', 'doc2.txt', 'doc3.txt']
# vaccine: ['doc1.txt', 'doc2.txt', 'doc3.txt', 'doc4.txt']
# valid: ['doc3.txt']
# variable: ['doc3.txt']
# various: ['doc3.txt']
# vary: ['doc2.txt']
# varying: ['doc3.txt']
# vast: ['doc3.txt']
# verbatim: ['doc1.txt']
# version: ['doc1.txt', 'doc4.txt']
# via: ['doc3.txt']
# virus: ['doc3.txt']
# website: ['doc3.txt']
# whether: ['doc3.txt']
# woman: ['doc1.txt']
# working: ['doc3.txt']
# world: ['doc4.txt']
# year: ['doc2.txt', 'doc4.txt']
# zanzibar: ['doc4.txt']
# Query: 'vaccine AND time' => Documents: ['doc2.txt', 'doc4.txt']
# Query: 'vaccine OR utilized' => Documents: ['doc1.txt', 'doc2.txt', 'doc4.txt', 'doc3.txt']
# Query: 'NOT version' => Documents: ['doc3.txt', 'doc2.txt']
# Query: 'version' => Documents: ['doc1.txt', 'doc4.txt']
# [nltk_data] Downloading package punkt to C:\Users\Subhassini
# [nltk_data]     Sridharan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Subhassini
# [nltk_data]     Sridharan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Subhassini
# [nltk_data]     Sridharan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
